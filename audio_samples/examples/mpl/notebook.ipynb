# %%
import audio_samples as aus

# %%
sine = aus.sine_wave(440, 1.0, 8000)
sine
# Out:
# AudioSamples<f32>: 1 ch × 8000 samples @ 8000 Hz (NonInterleaved)
# Mono Channel
#   First 5 samples: [0.0000, 0.3387, 0.6374, 0.8607, 0.9823]
#   Last 5 samples: [-0.9877, -0.9823, -0.8607, -0.6374, -0.3387]

# %%
from audio_samples.mpl import plot_waveform, plot_spectrogram

plot_waveform(sine)
plot_spectrogram(sine)
# Out:
# (<Figure size 1200x600 with 2 Axes>,
#  <Axes: title={'center': 'Spectrogram'}, xlabel='Time (s)', ylabel='Frequency (Hz)'>)
